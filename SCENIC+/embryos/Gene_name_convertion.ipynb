# %%
import dill
infile = open('/home/adufour/work/scenic_omics/embryos/SCENIC/scplus_obj.pkl', 'rb')
scplus_obj = dill.load(infile)
infile.close()

# %%
from scenicplus.utils import format_egrns
format_egrns(scplus_obj, eregulons_key = 'eRegulons_importance', TF2G_key = 'TF2G_adj', key_added = 'eRegulon_metadata')

# %%
scplus_obj.uns['eRegulon_metadata']
# Out:
#                     Region_signature_name  \
# 0           ENSSSCG00000000272_+_+_(174r)
# 1           ENSSSCG00000000272_+_+_(174r)
# 2           ENSSSCG00000000272_+_+_(174r)
# 3           ENSSSCG00000000272_+_+_(174r)
# 4           ENSSSCG00000000272_+_+_(174r)
# ..                                    ...
# 15  ENSSSCG00000037647_extended_-_-_(14r)
# 16  ENSSSCG00000037647_extended_-_-_(14r)
# 17  ENSSSCG00000037647_extended_-_-_(14r)
# 18  ENSSSCG00000037647_extended_-_-_(14r)
# 19  ENSSSCG00000037647_extended_-_-_(14r)
#
#                       Gene_signature_name                  TF is_extended  \
# 0            ENSSSCG00000000272_+_+_(72g)  ENSSSCG00000000272       False
# 1            ENSSSCG00000000272_+_+_(72g)  ENSSSCG00000000272       False
# 2            ENSSSCG00000000272_+_+_(72g)  ENSSSCG00000000272       False
# 3            ENSSSCG00000000272_+_+_(72g)  ENSSSCG00000000272       False
# 4            ENSSSCG00000000272_+_+_(72g)  ENSSSCG00000000272       False
# ..                                    ...                 ...         ...
# 15  ENSSSCG00000037647_extended_-_-_(12g)  ENSSSCG00000037647        True
# 16  ENSSSCG00000037647_extended_-_-_(12g)  ENSSSCG00000037647        True
# 17  ENSSSCG00000037647_extended_-_-_(12g)  ENSSSCG00000037647        True
# 18  ENSSSCG00000037647_extended_-_-_(12g)  ENSSSCG00000037647        True
# 19  ENSSSCG00000037647_extended_-_-_(12g)  ENSSSCG00000037647        True
#
#                    Region                Gene  R2G_importance   R2G_rho  \
# 0   1:107949712-107950212  ENSSSCG00000004558        0.021216  0.132060
# 1   1:107659273-107659773  ENSSSCG00000004558        0.008690  0.082422
# 2   1:107689786-107690286  ENSSSCG00000004558        0.021383  0.123316
# 3   1:107886380-107886880  ENSSSCG00000004558        0.056425  0.161613
# 4   1:107949165-107949665  ENSSSCG00000004558        0.010226  0.100105
# ..                    ...                 ...             ...       ...
# 15   14:88473878-88474378  ENSSSCG00000010370        0.014041 -0.143928
# 16    5:32970064-32970564  ENSSSCG00000032595        0.016981 -0.109311
# 17    5:32981053-32981553  ENSSSCG00000032595        0.030084 -0.226317
# 18  1:163790120-163790620  ENSSSCG00000044382        0.033541 -0.113878
# 19   12:26842989-26843489  ENSSSCG00000017566        0.031242 -0.393878
#
#     R2G_importance_x_rho  R2G_importance_x_abs_rho  TF2G_importance  \
# 0               0.002802                  0.002802         0.877556
# 1               0.000716                  0.000716         0.877556
# 2               0.002637                  0.002637         0.877556
# 3               0.009119                  0.009119         0.877556
# 4               0.001024                  0.001024         0.877556
# ..                   ...                       ...              ...
# 15             -0.002021                  0.002021         0.678860
# 16             -0.001856                  0.001856         0.506837
# 17             -0.006809                  0.006809         0.506837
# 18             -0.003820                  0.003820         0.805091
# 19             -0.012305                  0.012305         0.380228
#
#     TF2G_regulation  TF2G_rho  TF2G_importance_x_abs_rho  \
# 0                 1  0.166144                   0.145801
# 1                 1  0.166144                   0.145801
# 2                 1  0.166144                   0.145801
# 3                 1  0.166144                   0.145801
# 4                 1  0.166144                   0.145801
# ..              ...       ...                        ...
# 15               -1 -0.162168                  -0.110089
# 16               -1 -0.149248                  -0.075644
# 17               -1 -0.149248                  -0.075644
# 18               -1 -0.107096                  -0.086222
# 19               -1 -0.207675                  -0.078964
#
#     TF2G_importance_x_rho
# 0                0.145801
# 1                0.145801
# 2                0.145801
# 3                0.145801
# 4                0.145801
# ..                    ...
# 15               0.110089
# 16               0.075644
# 17               0.075644
# 18               0.086222
# 19               0.078964
#
# [41413 rows x 15 columns]

# %%
def gene_convert(gene_list):
    from gprofiler import GProfiler
    import numpy as np
    gp = GProfiler(return_dataframe=True)
    x = np.array(gene_list)
    gene_list_convert = gp.convert(organism='sscrofa', query=np.unique(x).tolist())
    gene_list_convert['name'] = np.where(gene_list_convert['name'] == 'None', gene_list_convert['incoming'], gene_list_convert['name'])
    return gene_list_convert

# %%
list_tf = gene_convert(scplus_obj.uns['eRegulon_metadata']['TF'].tolist())
list_gene = gene_convert(scplus_obj.uns['eRegulon_metadata']['Gene'].tolist())

# %%
scplus_obj.uns['eRegulon_metadata']['TF'] = scplus_obj.uns['eRegulon_metadata']['TF'].replace(list_tf['incoming'].tolist(), list_tf['name'].tolist())

# %%
scplus_obj.uns['eRegulon_metadata']['Gene'] = scplus_obj.uns['eRegulon_metadata']['Gene'].replace(list_gene['incoming'].tolist(), list_gene['name'].tolist())

# %%
def gene_convert_part(gene_list):
    from gprofiler import GProfiler
    import numpy as np
    gp = GProfiler(return_dataframe=True)
    x = np.array(gene_list)
    x = np.unique(x).tolist()
    part_a = [item.split('_', 1)[0] for item in x]
    part_convert = gp.convert(organism='sscrofa', query=part_a)
    part_convert['name'] = np.where(part_convert['name'] == 'None', part_convert['incoming'], part_convert['name'])
    part_b = [item.split('_', 1)[1] for item in x]
    region_list = [f"{itema}_{itemb}" for itema, itemb in zip(part_convert['name'], part_b)]
    return x, region_list

# %%
source, replacement = gene_convert_part(scplus_obj.uns['eRegulon_metadata']['Region_signature_name'].tolist())
scplus_obj.uns['eRegulon_metadata']['Region_signature_name'] = scplus_obj.uns['eRegulon_metadata']['Region_signature_name'].replace(source, replacement)

# %%
source, replacement = gene_convert_part(scplus_obj.uns['eRegulon_metadata']['Gene_signature_name'].tolist())
scplus_obj.uns['eRegulon_metadata']['Gene_signature_name'] = scplus_obj.uns['eRegulon_metadata']['Gene_signature_name'].replace(source, replacement)

# %%
scplus_obj.uns['eRegulon_metadata']
# Out:
#        Region_signature_name       Gene_signature_name     TF is_extended  \
# 0             SP1_+_+_(174r)             SP1_+_+_(72g)    SP1       False
# 1             SP1_+_+_(174r)             SP1_+_+_(72g)    SP1       False
# 2             SP1_+_+_(174r)             SP1_+_+_(72g)    SP1       False
# 3             SP1_+_+_(174r)             SP1_+_+_(72g)    SP1       False
# 4             SP1_+_+_(174r)             SP1_+_+_(72g)    SP1       False
# ..                       ...                       ...    ...         ...
# 15  TFDP2_extended_-_-_(14r)  TFDP2_extended_-_-_(12g)  TFDP2        True
# 16  TFDP2_extended_-_-_(14r)  TFDP2_extended_-_-_(12g)  TFDP2        True
# 17  TFDP2_extended_-_-_(14r)  TFDP2_extended_-_-_(12g)  TFDP2        True
# 18  TFDP2_extended_-_-_(14r)  TFDP2_extended_-_-_(12g)  TFDP2        True
# 19  TFDP2_extended_-_-_(14r)  TFDP2_extended_-_-_(12g)  TFDP2        True
#
#                    Region                Gene  R2G_importance   R2G_rho  \
# 0   1:107949712-107950212             CSNK1G1        0.021216  0.132060
# 1   1:107659273-107659773             CSNK1G1        0.008690  0.082422
# 2   1:107689786-107690286             CSNK1G1        0.021383  0.123316
# 3   1:107886380-107886880             CSNK1G1        0.056425  0.161613
# 4   1:107949165-107949665             CSNK1G1        0.010226  0.100105
# ..                    ...                 ...             ...       ...
# 15   14:88473878-88474378  ENSSSCG00000010370        0.014041 -0.143928
# 16    5:32970064-32970564               RAP1B        0.016981 -0.109311
# 17    5:32981053-32981553               RAP1B        0.030084 -0.226317
# 18  1:163790120-163790620  ENSSSCG00000044382        0.033541 -0.113878
# 19   12:26842989-26843489               ACSF2        0.031242 -0.393878
#
#     R2G_importance_x_rho  R2G_importance_x_abs_rho  TF2G_importance  \
# 0               0.002802                  0.002802         0.877556
# 1               0.000716                  0.000716         0.877556
# 2               0.002637                  0.002637         0.877556
# 3               0.009119                  0.009119         0.877556
# 4               0.001024                  0.001024         0.877556
# ..                   ...                       ...              ...
# 15             -0.002021                  0.002021         0.678860
# 16             -0.001856                  0.001856         0.506837
# 17             -0.006809                  0.006809         0.506837
# 18             -0.003820                  0.003820         0.805091
# 19             -0.012305                  0.012305         0.380228
#
#     TF2G_regulation  TF2G_rho  TF2G_importance_x_abs_rho  \
# 0                 1  0.166144                   0.145801
# 1                 1  0.166144                   0.145801
# 2                 1  0.166144                   0.145801
# 3                 1  0.166144                   0.145801
# 4                 1  0.166144                   0.145801
# ..              ...       ...                        ...
# 15               -1 -0.162168                  -0.110089
# 16               -1 -0.149248                  -0.075644
# 17               -1 -0.149248                  -0.075644
# 18               -1 -0.107096                  -0.086222
# 19               -1 -0.207675                  -0.078964
#
#     TF2G_importance_x_rho
# 0                0.145801
# 1                0.145801
# 2                0.145801
# 3                0.145801
# 4                0.145801
# ..                    ...
# 15               0.110089
# 16               0.075644
# 17               0.075644
# 18               0.086222
# 19               0.078964
#
# [41413 rows x 15 columns]

# %%
list_gene = gene_convert(scplus_obj.metadata_genes['gene_ids'].tolist())

# %%
scplus_obj.metadata_genes['gene_ids'] = scplus_obj.metadata_genes['gene_ids'].replace(list_gene['incoming'].tolist(), list_gene['name'].tolist())

# %%
from numpy import copy
newArray = copy(scplus_obj.metadata_genes.index.values)
for k, v in zip(list_gene['incoming'].tolist(), list_gene['name'].tolist()): scplus_obj.metadata_genes.index.values[scplus_obj.metadata_genes.index.values==k] = v

# %%
scplus_obj.metadata_genes
# Out:
#                               gene_ids    feature_types  \
# gene_ids
# ENSSSCG00000048769  ENSSSCG00000048769  Gene Expression
# PSMB1                            PSMB1  Gene Expression
# DLL1                              DLL1  Gene Expression
# DYNLT2                          DYNLT2  Gene Expression
# PHF10                            PHF10  Gene Expression
# ...                                ...              ...
# ENSSSCG00000036928  ENSSSCG00000036928  Gene Expression
# ENSSSCG00000040795  ENSSSCG00000040795  Gene Expression
# ENSSSCG00000023819  ENSSSCG00000023819  Gene Expression
# SRY                                SRY  Gene Expression
# ENSSSCG00000034141  ENSSSCG00000034141  Gene Expression
#
#                                            genome
# gene_ids
# ENSSSCG00000048769  sus_scrofa_11_ensembl_arc_108
# PSMB1               sus_scrofa_11_ensembl_arc_108
# DLL1                sus_scrofa_11_ensembl_arc_108
# DYNLT2              sus_scrofa_11_ensembl_arc_108
# PHF10               sus_scrofa_11_ensembl_arc_108
# ...                                           ...
# ENSSSCG00000036928  sus_scrofa_11_ensembl_arc_108
# ENSSSCG00000040795  sus_scrofa_11_ensembl_arc_108
# ENSSSCG00000023819  sus_scrofa_11_ensembl_arc_108
# SRY                 sus_scrofa_11_ensembl_arc_108
# ENSSSCG00000034141  sus_scrofa_11_ensembl_arc_108
#
# [35670 rows x 3 columns]

# %%
# Format eRegulons
from scenicplus.eregulon_enrichment import *
get_eRegulons_as_signatures(scplus_obj, eRegulon_metadata_key='eRegulon_metadata', key_added='eRegulon_signatures')

# %%
## Score chromatin layer
# Region based raking
from scenicplus.cistromes import *
import time
start_time = time.time()
region_ranking = make_rankings(scplus_obj, target='region')
# Score region regulons
score_eRegulons(scplus_obj,
                ranking = region_ranking,
                eRegulon_signatures_key = 'eRegulon_signatures',
                key_added = 'eRegulon_AUC',
                enrichment_type= 'region',
                auc_threshold = 0.05,
                normalize = False,
                n_cpu = 1)
time = time.time()-start_time
print(time/60)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 241/241 [00:25<00:00,  9.62it/s]
# 5.779541083176931

# %%
## Score transcriptome layer
# Gene based raking
from scenicplus.cistromes import *
import time
start_time = time.time()
gene_ranking = make_rankings(scplus_obj, target='gene')
# Score gene regulons
score_eRegulons(scplus_obj,
                gene_ranking,
                eRegulon_signatures_key = 'eRegulon_signatures',
                key_added = 'eRegulon_AUC',
                enrichment_type = 'gene',
                auc_threshold = 0.05,
                normalize= False,
                n_cpu = 1)
time = time.time()-start_time
print(time/60)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 241/241 [00:15<00:00, 15.93it/s]
# 1.1655084490776062

# %%
# Generate pseudobulks
import time
start_time = time.time()
generate_pseudobulks(scplus_obj,
                         variable = 'GEX_Clusters_Time',
                         auc_key = 'eRegulon_AUC',
                         signature_key = 'Gene_based',
                         nr_cells = 1,
                         nr_pseudobulks = 100,
                         seed=555)
generate_pseudobulks(scplus_obj,
                         variable = 'GEX_Clusters_Time',
                         auc_key = 'eRegulon_AUC',
                         signature_key = 'Region_based',
                         nr_cells = 1,
                         nr_pseudobulks = 100,
                         seed=555)
time = time.time()-start_time
print(time/60)
# Out:
# 0.43292161226272585

# %% [raw]
# %matplotlib inline
# import seaborn as sns
# sns.set_style("white")
# colors = ["#E9842C","#F8766D", "#BC9D00", "#00C0B4", "#9CA700", "#6FB000", "#00B813", "#00BD61", "#00C08E", "#00BDD4",
#            "#00A7FF", "#7F96FF", "#E26EF7", "#FF62BF", "#D69100", "#BC81FF"]
# categories = sorted(set(scplus_obj.metadata_cell['GEX_Clusters']))
# color_dict = dict(zip(categories, colors[0:len(categories)]))
# prune_plot(scplus_obj,
#            'NANOG_+_+',
#            pseudobulk_variable = 'GEX_Clusters',
#            show_dot_plot = True,
#            show_line_plot = False,
#            color_dict = color_dict,
#            use_pseudobulk = True,
#            auc_key = 'eRegulon_AUC',
#            signature_key = 'Region_based',
#            seed=555)

# %% [raw]
# # Gene based
# %matplotlib inline
# sns.set_style("white")
# colors = ["#E9842C","#F8766D", "#BC9D00", "#00C0B4", "#9CA700", "#6FB000", "#00B813", "#00BD61", "#00C08E", "#00BDD4",
#            "#00A7FF", "#7F96FF", "#E26EF7", "#FF62BF", "#D69100", "#BC81FF"]
# categories = sorted(set(scplus_obj.metadata_cell['GEX_Clusters']))
# color_dict = dict(zip(categories, colors[0:len(categories)]))
# prune_plot(scplus_obj,
#            'NANOG_+_+',
#            pseudobulk_variable = 'GEX_Clusters',
#            show_dot_plot = True,
#            show_line_plot = False,
#            color_dict = color_dict,
#            use_pseudobulk = True,
#            auc_key = 'eRegulon_AUC',
#            signature_key = 'Gene_based',
#            seed=555)

# %%
# Correlation between region based regulons and gene based regulons
import pandas
df1 = scplus_obj.uns['eRegulon_AUC']['Gene_based'].copy()
df2 = scplus_obj.uns['eRegulon_AUC']['Region_based'].copy()
df1.columns = [x.split('_(')[0] for x in df1.columns]
df2.columns = [x.split('_(')[0] for x in df2.columns]
correlations = df1.corrwith(df2, axis = 0)
correlations = correlations[abs(correlations) > 0.2]
# Kepp only R2G +
keep = [x for x in correlations.index if '+_+' in x] + [x for x in correlations.index if '-_+' in x]
# Keep extended if not direct
extended = [x for x in keep if 'extended' in x]
direct = [x for x in keep if not 'extended' in x]
keep_extended = [x for x in extended if not x.replace('extended_', '') in direct]
keep = direct + keep_extended
# Keep regulons with more than 10 genes
keep_gene = [x for x in scplus_obj.uns['eRegulon_AUC']['Gene_based'].columns if x.split('_(')[0] in keep]
keep_gene = [x for x in keep_gene if (int(x.split('_(')[1].replace('g)', '')) > 10)]
keep_all = [x.split('_(')[0] for x in keep_gene]
keep_region = [x for x in scplus_obj.uns['eRegulon_AUC']['Region_based'].columns if x.split('_(')[0] in keep]
scplus_obj.uns['selected_eRegulons'] = {}
scplus_obj.uns['selected_eRegulons']['Gene_based'] = keep_gene
scplus_obj.uns['selected_eRegulons']['Region_based'] = keep_region

# %%
import dill as dill

# %%
dill.dump(scplus_obj, open('/home/adufour/work/scenic_omics/embryos/SCENIC/scplus_obj.pkl', 'wb'))
